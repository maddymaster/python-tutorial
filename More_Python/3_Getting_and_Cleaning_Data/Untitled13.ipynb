# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/eJ5zayg0OnnX5PqMvAR8KQd9p/titanicmod.csv')
df1 = df[df.isnull().sum(axis=1) > 2]

# %%
df1
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Year, Ship, Movie Director]
# Index: []

# %%
nunique = df.apply(pd.Series.nunique)
cols_to_drop = nunique[nunique == 1].index
df2=df.drop(cols_to_drop, axis=1)
print(df2)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0       0.000000     1.0                                   Kelly, Mr. James
# 1       0.002398     1.0                   Wilkes, Mrs. James (Ellen Needs)
# 2       0.004796     0.5                          Myles, Mr. Thomas Francis
# 3       0.007194     1.0                                   Wirz, Mr. Albert
# 4       0.009592     1.0       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5       0.011990     1.0                         Svensson, Mr. Johan Cervin
# 6       0.014388     1.0                               Connolly, Miss. Kate
# 7       0.016787     0.5                       Caldwell, Mr. Albert Francis
# 8       0.019185     1.0          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9       0.021583     1.0                            Davies, Mr. John Samuel
# 10      0.023981     1.0                                   Ilieff, Mr. Ylio
# ...

# %%
df3 = df.select_dtypes(include=['int', 'float'])
#print(df3.columns)
colsToPass = df3.columns

# %%
df[colsToPass]=df[colsToPass].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
print(df.describe())
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   418.000000  418.000000  332.000000  418.000000  418.000000
# mean      0.500000    0.632775    0.396975    0.055921    0.043594
# std       0.289713    0.420919    0.187013    0.112095    0.109048
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       0.250000    0.000000    0.274693    0.000000    0.000000
# 50%       0.500000    1.000000    0.353818    0.000000    0.000000
# 75%       0.750000    1.000000    0.512066    0.125000    0.000000
# max       1.000000    1.000000    1.000000    1.000000    1.000000
#
#              Fare        Year
# count  417.000000  418.000000
# mean     0.069540    0.496860
# std      0.109124    0.299910
# min      0.000000    0.000000
# 25%      0.015412    0.229167
# 50%      0.028213    0.479167
# 75%      0.061484    0.769097
# max      1.000000    1.000000

# %%
df.Year
# Out:
# 0      0.326389
# 1      0.972222
# 2      0.763889
# 3      0.243056
# 4      0.368056
# 5      0.256944
# 6      0.041667
# 7      0.805556
# 8      0.729167
# 9      0.423611
# 10     0.673611
# 11     0.243056
# 12     0.243056
# 13     0.423611
# 14     0.131944
# 15     0.458333
# 16     1.000000
# 17     0.979167
# 18     0.111111
# 19     0.645833
# 20     0.583333
# 21     0.576389
# 22     0.888889
# 23     0.791667
# 24     0.750000
# 25     0.777778
# 26     0.826389
# 27     0.069444
# 28     0.236111
# 29     0.722222
#          ...
# 388    0.159722
# 389    0.951389
# 390    0.111111
# 391    0.187500
# 392    0.881944
# 393    0.562500
# 394    1.000000
# 395    0.388889
# 396    0.388889
# 397    0.256944
# 398    0.486111
# 399    0.166667
# 400    0.194444
# 401    0.736111
# 402    0.868056
# 403    0.458333
# 404    0.916667
# 405    0.527778
# 406    0.833333
# 407    0.875000
# 408    0.298611
# 409    0.388889
# 410    0.472222
# 411    0.069444
# ...

# %%
df = df[df.isnull().sum(axis=1) <= 5]

# look at the summary again
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# PassengerId        0.00
# Pclass             0.00
# Name               0.00
# Sex                0.00
# Age               20.57
# SibSp              0.00
# Parch              0.00
# Ticket             0.00
# Fare               0.24
# Cabin             78.23
# Embarked           0.00
# Year               0.00
# Ship               0.00
# Movie Director     0.00
# dtype: float64

# %%
df = df.drop_duplicates()
print(df)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0       0.000000     1.0                                   Kelly, Mr. James
# 1       0.002398     1.0                   Wilkes, Mrs. James (Ellen Needs)
# 2       0.004796     0.5                          Myles, Mr. Thomas Francis
# 3       0.007194     1.0                                   Wirz, Mr. Albert
# 4       0.009592     1.0       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5       0.011990     1.0                         Svensson, Mr. Johan Cervin
# 6       0.014388     1.0                               Connolly, Miss. Kate
# 7       0.016787     0.5                       Caldwell, Mr. Albert Francis
# 8       0.019185     1.0          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9       0.021583     1.0                            Davies, Mr. John Samuel
# 10      0.023981     1.0                                   Ilieff, Mr. Ylio
# ...

# %%
df = df[~np.isnan(df['Year'])]

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0       0.000000     1.0                                   Kelly, Mr. James
# 1       0.002398     1.0                   Wilkes, Mrs. James (Ellen Needs)
# 2       0.004796     0.5                          Myles, Mr. Thomas Francis
# 3       0.007194     1.0                                   Wirz, Mr. Albert
# 4       0.009592     1.0       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5       0.011990     1.0                         Svensson, Mr. Johan Cervin
# 6       0.014388     1.0                               Connolly, Miss. Kate
# 7       0.016787     0.5                       Caldwell, Mr. Albert Francis
# 8       0.019185     1.0          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9       0.021583     1.0                            Davies, Mr. John Samuel
# 10      0.023981     1.0                                   Ilieff, Mr. Ylio
# ...
