# %%
import pandas as pd 
import sys,ast
import numpy as np
df=pd.read_csv('./popularity.csv')

# %%
df.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# ...

# %%
df[' shares'].mean()
# Out:
# 3395.3801836343455

# %%
elements = np.array(df)

# %%
mean = np.mean(elements, axis=0)
sd = np.std(elements, axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a39584e2ef26> in <module>()
# ----> 1 mean = np.mean(elements, axis=0)
#       2 sd = np.std(elements, axis=0)
#       3 mean
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2957                           out=out, **kwargs)
#    2958
#    2959
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
# ---> 73                 ret, rcount, out=ret, casting='unsafe', subok=False)
#      74         if is_float16_result and out is None:
#      75             ret = arr.dtype.type(ret)
#
# ...

# %%
final_list = [x for x in df if (x > mean - 2 * sd )]

final_list = [ x for x in final_list if (x < mean + 2 * sd)]
