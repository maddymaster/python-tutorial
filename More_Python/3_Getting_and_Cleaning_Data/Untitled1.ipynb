# %%
import numpy as np
import pandas as pd

marks = pd.read_csv("https://query.data.world/s/HqjNNadqEnwSq1qnoV_JqyRJkc7o6O")
marks.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
marks[marks.isnull().sum(axis=1) < 5]
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final
# 0        5       57.14     34.09    64.38     51.48   52.50
# 1        8       95.05    105.49    67.50     99.07   68.33
# 2        8       83.70     83.17    30.00     63.15   48.89
# 3        7       81.22     96.06    49.38    105.93   80.56
# 4        8       91.32     93.64    95.00    107.41   73.89
# 5        7       95.00     92.58    93.12     97.78   68.06
# 6        8       95.05    102.99    56.25     99.07   50.00
# 7        7       72.85     86.85    60.00       NaN   56.11
# 8        8       84.26     93.10    47.50     18.52   50.83
# 9        7       90.10     97.55    51.25     88.89   63.61
# 10       7       80.44     90.20    75.00     91.48   39.72
# 11       6       86.26       NaN      NaN     87.59   77.50
# 12       8       97.16       NaN      NaN     93.52   63.33
# 13       7       91.28       NaN      NaN     99.81   92.22
# 14       8       84.80       NaN      NaN     16.91   35.83
# ...

# %%
len(marks[marks.isnull().sum(axis=1) < 5].index)
# Out:
# 97

# %%
print(marks.isnull().sum())
# Out:
# Prefix         0
# Assignment     2
# Tutorial      12
# Midterm       16
# TakeHome       9
# Final          5
# dtype: int64

# %%
marks.isnull().all(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Length: 99, dtype: bool

# %%
marks.isnull().all(axis=1).sum()
# Out:
# 0

# %%
(marks[marks.isnull().sum(axis=1) < 5])
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final
# 0        5       57.14     34.09    64.38     51.48   52.50
# 1        8       95.05    105.49    67.50     99.07   68.33
# 2        8       83.70     83.17    30.00     63.15   48.89
# 3        7       81.22     96.06    49.38    105.93   80.56
# 4        8       91.32     93.64    95.00    107.41   73.89
# 5        7       95.00     92.58    93.12     97.78   68.06
# 6        8       95.05    102.99    56.25     99.07   50.00
# 7        7       72.85     86.85    60.00       NaN   56.11
# 8        8       84.26     93.10    47.50     18.52   50.83
# 9        7       90.10     97.55    51.25     88.89   63.61
# 10       7       80.44     90.20    75.00     91.48   39.72
# 11       6       86.26       NaN      NaN     87.59   77.50
# 12       8       97.16       NaN      NaN     93.52   63.33
# 13       7       91.28       NaN      NaN     99.81   92.22
# 14       8       84.80       NaN      NaN     16.91   35.83
# ...

# %%
100*(len(marks[marks.isnull().sum(axis=1) == 5 ].index) / len(marks.index))
# Out:
# 2.0202020202020203

# %%
df = marks[~np.isnan([marks.isnull().sum(axis=1) == 5 ].index)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-19e1ff67fdae> in <module>()
# ----> 1 df = marks[~np.isnan(marks.isnull().sum(axis=1) == 5 .index)]
#
# AttributeError: 'int' object has no attribute 'index'

# %%
marks = marks[~(marks <= 5)]

# %%
marks.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0     NaN       57.14     34.09    64.38     51.48  52.50
# 1     8.0       95.05    105.49    67.50     99.07  68.33
# 2     8.0       83.70     83.17    30.00     63.15  48.89
# 3     7.0       81.22     96.06    49.38    105.93  80.56
# 4     8.0       91.32     93.64    95.00    107.41  73.89

# %%
marks = marks[~np.isnan(marks ==5)]
